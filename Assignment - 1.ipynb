# %% [markdown]
# # Assignment - 1

# %% [markdown]
# ### 1. Write a Python script to show the output as
# ### a. ”I’m a ’Student’ of ITER.”
# ### b. ’My Name is \n Khan.’

# %%
print("I\'m a \'Student\' of ITER'")
print("\'My Name is \n Khan'")
# Out:
# I'm a 'Student' of ITER'
# 'My Name is
#  Khan'

# %% [markdown]
# ### 2. Find the outputs for the following scripts.
# ### a. 5 and 6
# ### b. 0 and 6
# ### c. 0 or 1
# ### d. 1 or 0
# ### e. -7*20+8/16*2+54
# ### f. 5%10+10-25*8//5
# ### e. ’hello’*(2-5)
# ### f. ’hi’ > ’hello’ or ’bye’ < ’Bye’
# ### g. 10 !=9 and 29 >= 29 and ’hi’ > ’hello’ or ’bye’ < ’Bye’ and 7 <= 2.5

# %%
print(5 and 6)
print(0 and 6)
print(0 or 1)
print(1 or 0)
print(-720 + 8 / 162 + 54)
print(5 % 10 + 10 - 25 * 8 // 5)
print('hello' * (2-5))
print('hi' > 'hello' or 'bye' < 'Bye')
print(10 != 9 and 29 >= 29 and 'hi' > 'hello' or 'bye' < 'Bye' and 7 <= 2.5)
# Out:
# 6
# 0
# 1
# 1
# -665.9506172839506
# -25
#
# True
# True

# %% [markdown]
# ### 3. Differentiate between the following and give examples:
# ### a. = and ==
# ### b. / and
# ### c. / and //
# ### d. * and **
# ### e. x=x*10 and x*=x*10
# ### f. Interpreted language and compiled language
# ### g. Data scientist and Data Analyst
# ### h. \ and /

# %% [markdown]
# #### Answer

# %% [markdown]
#  ###
# a. = and ==:
#    - '=' is the assignment operator used to assign a value to a variable. For example, `x = 5` assigns the value 5 to the variable x.
#    - '==' is the equality operator used to compare two values for equality. For example, `x == 5` is a Boolean expression that evaluates to True if x is equal to 5 and False if it's not.
#  ###

# %%
x = 5
print(x)
print(x == 3)
# Out:
# 5
# False

# %% [markdown]
#  ###
# b. / and //:
#    - '/' is the division operator in most programming languages and gives the result as a floating-point or decimal number. For example, 7 / 3 results in 2.3333.
#    - '//' is the floor division operator that gives the integer part of the division result, effectively truncating the decimal part. For example, 7 // 3 results in 2.
#  ###

# %%
print(5 / 2)
print(5 // 2)
# Out:
# 2.5
# 2

# %% [markdown]
#  ###
# d. * and **:
#    - '*' is the multiplication operator used to multiply two numbers. For example, 3 * 4 results in 12.
#    - '**' is the exponentiation operator used to raise a number to a power. For example, 2 ** 3 results in 8 (2 raised to the power of 3).
#  ###

# %%
print(2 * 5)
print(2 ** 5)
# Out:
# 10
# 32

# %% [markdown]
#  ###
# e. x=x10 and x=x*10:
#    - 'x=x10' is not a common programming expression, and it would typically be considered a syntax error. It suggests assigning the value 'x10' to the variable x, which is not standard practice.
#    - 'x=x*10' is a valid expression that multiplies the current value of the variable x by 10 and assigns the result back to x.
#  ###

# %%
# x = x * 10
x *= x * 10
x
# Out:
# 25000

# %% [markdown]
#  ###
# f. Interpreted language and compiled language:
#    - An interpreted language is a programming language where the source code is executed directly by an interpreter at runtime. Examples include Python, Ruby, and JavaScript.
#    - A compiled language is a programming language where the source code is translated into machine code or an intermediate code by a compiler before execution. Examples include C, C++, and Rust.
#  ###

# %% [markdown]
#  ###
# g. Data scientist and Data Analyst:
#    - A data scientist is a professional who uses advanced statistical and analytical techniques to analyze and interpret complex data. They often work with big data, machine learning, and data modeling to derive actionable insights and build predictive models.
#    - A data analyst is a professional who focuses on collecting, processing, and analyzing data to provide insights and support decision-making. They typically work with structured data and use tools like Excel, SQL, and data visualization software to generate reports and summaries.
#  ###

# %% [markdown]
#  ###
# h. \ and / (in the context of file paths):
#    - '\' is used as an escape character in many programming languages to indicate special characters or escape sequences (e.g., '\n' for a newline).
#    - '/' is commonly used as a directory separator in Unix-based systems and web addresses (URLs).
#  ###

# %% [markdown]
# ### 4. Construct logical expressions for representing the following conditions:
# ### a. marks scored should be greater than 300 and less than 400.
# ### b. Whether the value of grade is an uppercase letter.
# ### c. The post is engineer and experience is more than four years.

# %%
# a
mark = int(input("Enter the mark:- "))
if(mark > 300 and mark < 400):
    print("True")
else:
    print("False")
# Out:
# Enter the mark:- 5678
# False

# %%
# b.
grade = str(input("Enter the grade:- "))
if(ord(grade) > 65 and ord(grade) < 90):
    print("True")
elif(ord(grade) > 97 and ord(grade) < 122):
    print("False")
else:
    print("False")
# Out:
# Enter the grade:- t
# False

# %%
# c.
exp = int(input("Enter your experience:- "))
if(exp > 4):
    print("Eligible")
else:
    print("Not eligible")
# Out:
# Enter your experience:- 12
# Eligible

# %% [markdown]
# ### 5. Create a program that reads the length and width of a farmer’s field from the user in feet. Display the
# ### area of the field in acres. Hint: There are 43,560 square feet in an acre

# %%
length = int(input("Enter the length of the field:- "))
width = int(input("Enter the width of the field:- "))
acres = (length * width) / 43560
print(f"The area of the field in acres is {acres} acre")
# Out:
# Enter the length of the field:- 12
# Enter the width of the field:- 123
# The area of the field in acres is 0.033884297520661154 acre

# %% [markdown]
# ### 6. An online retailer sells two products: Soap and Shampoo. Each soap costs 75 rs. Each shampoo costs
# ### 111 rs. Write a program that reads the number of soaps and the number of shampoo from the user.
# ### Then your program should compute and display the total price for the order.

# %%
soap = int(input("Enter the number of soap:- "))
shampoo = int(input("Enter the number of shampoo:- "))
total = (soap * 75) + (shampoo * 111)
print(f"Total price for the order is {total} rs")
# Out:
# Enter the number of soap:- 123
# Enter the number of shampoo:- 12
# Total price for the order is 10557 rs

# %% [markdown]
# ![Screenshot%202023-10-01%20212114.png](attachment:Screenshot%202023-10-01%20212114.png)

# %%
import math
height = int(input("Enter the height:- "))
vi = 0
a = 9.8
vf = math.pow(vi ** 2 + 2 * a * height, 0.5)
print(vf)
# Out:
# Enter the height:- 12
# 15.336231610144651

# %% [markdown]
# ### 8. Write a program that reads a four-digit integer from the user and displays the sum of its digits. For
# ### example, if the user enters 3141 then your program should display 3 + 1 + 4 + 1 = 9.

# %%
num = int(input("Enter the four digit integer:- "))
sum = 0
while(num > 1):
    sum = sum + num % 10
    num = num // 10
print(sum)
# Out:
# Enter the four digit integer:- 3141
# 9

# %% [markdown]
# ### 9. Write a program that reads three integers from the user and displays them in sorted order (from
# ### smallest to largest). Use the min and max functions to find the smallest and largest values. The middle
# ### value can be found by computing the sum of all three values, and then subtracting the minimum value
# ### and the maximum value.

# %%
a = int(input("Enter the first number:- "))
b = int(input("Enter the second number:- "))
c = int(input("Enter the third number:- "))
print(max(a, b, c))
print(a + b + c - max(a, b, c) - min(a, b, c))
print(min(a, b, c))
# Out:
# Enter the first number:- 2
# Enter the second number:- 4
# Enter the third number:- 1
# 4
# 2
# 1

# %% [markdown]
# ### 10. Create a program that reads duration from the user as a number of days, hours, minutes, and seconds.
# ### Compute and display the total number of seconds represented by this duration.

# %%
day = int(input("Enter the number of day:- "))
hour = int(input("Enter the hour:- "))
minute = int(input("Enter the minute:- "))
second = int(input("Enter the second:- "))
print(day * 12 * 60 * 60 + hour * 60 * 60 + minute * 60 + second)
# Out:
# Enter the number of day:- 2
# Enter the hour:- 3
# Enter the minute:- 4
# Enter the second:- 5
# 97445

# %% [markdown]
# ![Screenshot%202023-10-01%20233009.png](attachment:Screenshot%202023-10-01%20233009.png)

# %%
r = int(input("Enter the radius:- "))
print(math.pi * r ** 2)
print(4 / 3 * math.pi * r ** 3)
# Out:
# Enter the radius:- 2
# 12.566370614359172
# 33.510321638291124

# %% [markdown]
# ### 12. Find the output and describe the mnethod that is used in the question.
# ### Let the string str is given by
# ### str= Hey! Hello!, Can you hear me, Mr. Hello?
# ### a. len(str)
# ### b. str.upper()
# ### c. str.lower()
# ### d. str.title()
# ### e. str.capitalize()
# ### f. str.swapcase()
# ### g. str.split(’,’)
# ### h. str.find(’He’)
# ### i. str.rfind(’He’)
# ### j. str.find(’He’,4,12)
# ### k. str.isalpha()
# ### l. str.islower()
# ### i. str.count(’He’)
# ### j. str.count(’He’,3,10)
# ### k. str.startswith(”Hey”)
# ### l. str.rstrip(’H’)
# ### m. str.replace(’Hello’, ’Virat’)
# ### n. str.replace(’Hello’,’Virat’,1)
# ### o. str.endswith(’!’)
# ### p. str.partition(’!’)

# %%
str= "Hey! Hello!, Can you hear me, Mr. Hello?"
print(len(str))
print(str.upper())
print(str.lower())
print(str.title())
print(str.capitalize())
print(str.swapcase())
print(str.split(','))
print(str.find('He'))
print(str.rfind('He'))
print(str.find('He',4,12))
print(str.isalpha())
print(str.islower())
print(str.count('He'))
print(str.count('He',3,10))
print(str.startswith("Hey"))
print(str.rstrip('H'))
print(str.replace('Hello', 'Virat'))
print(str.replace('Hello','Virat',1))
print(str.endswith('!'))
print(str.partition('!'))
# Out:
# 40
# HEY! HELLO!, CAN YOU HEAR ME, MR. HELLO?
# hey! hello!, can you hear me, mr. hello?
# Hey! Hello!, Can You Hear Me, Mr. Hello?
# Hey! hello!, can you hear me, mr. hello?
# hEY! hELLO!, cAN YOU HEAR ME, mR. hELLO?
# ['Hey! Hello!', ' Can you hear me', ' Mr. Hello?']
# 0
# 34
# 5
# False
# False
# 3
# 1
# True
# Hey! Hello!, Can you hear me, Mr. Hello?
# Hey! Virat!, Can you hear me, Mr. Virat?
# Hey! Virat!, Can you hear me, Mr. Hello?
# False
# ('Hey', '!', ' Hello!, Can you hear me, Mr. Hello?')

# %% [markdown]
# ### 13 For the string,
# ### str= Hey! Hello!, Can you hear me, Mr. Hello?
# ### write the outputs of the followings.
# ### a. str[4:7]
# ### b. str[:7]
# ### c. str[4:]
# ### d. str[-len(str): len(str)]
# ### e. str[:-5] + address[-3:]
# ### f. ’$’.join(str)

# %%
str= "Hey! Hello!, Can you hear me, Mr. Hello?"
print(str[4:7])
print(str[:7])
print(str[4:])
print(str[-len(str): len(str)])
print(str[:-5] + address[-3:])
print('$'.join(str))
# Out:
#  He
# Hey! He
#  Hello!, Can you hear me, Mr. Hello?
# Hey! Hello!, Can you hear me, Mr. Hello?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 6
#       4 print(str[4:])
#       5 print(str[-len(str): len(str)])
# ----> 6 print(str[:-5] + address[-3:])
#       7 print('$'.join(str))
#
# NameError: name 'address' is not defined
